# %% [markdown]
# # Predict house Price
#  Kaggle data set
#  Pericles Beirao
#  Version 01
#  19/02/2020
#
# Exploratory Analyse of the Train dataframe
# it will be used to develop the plan of attack

# %%
# load Library

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing


# %matplotlib inline

# %%
# Create the Data frame witht the observations 

HousePrices_train_DF = pd.read_csv('C:Data/house-prices-advanced-regression-techniques/train.csv',
                               sep=',',
                               header=0,
                               index_col=0,
                               dtype={
                                   'MSSubClass':'object',
                                   'OverallQual':'object',
                                   'OverallCond':'object'
                                    }
                                  )
pd.set_option('display.max_columns', 80)
print(HousePrices_train_DF.columns)
HousePrices_train_DF.head()
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
HousePrices_train_DF.describe()
# Out:
#        LotFrontage        LotArea    YearBuilt  YearRemodAdd   MasVnrArea  \
# count  1201.000000    1460.000000  1460.000000   1460.000000  1452.000000
# mean     70.049958   10516.828082  1971.267808   1984.865753   103.685262
# std      24.284752    9981.264932    30.202904     20.645407   181.066207
# min      21.000000    1300.000000  1872.000000   1950.000000     0.000000
# 25%      59.000000    7553.500000  1954.000000   1967.000000     0.000000
# 50%      69.000000    9478.500000  1973.000000   1994.000000     0.000000
# 75%      80.000000   11601.500000  2000.000000   2004.000000   166.000000
# max     313.000000  215245.000000  2010.000000   2010.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    443.639726    46.549315   567.240411  1057.429452  1162.626712
# std     456.098091   161.319273   441.866955   438.705324   386.587738
# ...

# %% [markdown]
# # Divide and conquest
#
# First I will look for variables that explain sales price by groups
#
# Will develop one data frame for each group
#
# Groups :
#     Lot
#     Gr

# %%
# Creating a direct path to the SalePrice

SalePrice = HousePrices_train_DF.SalePrice

# %%
# Create Lot DataFrame
'''
See the relationship of lot size and type with the price 
'''

Lot_DF = HousePrices_train_DF.loc[:,HousePrices_train_DF.columns.str.contains(pat='Lot')]
Lot_DF.dtypes
# Out:
# LotFrontage    float64
# LotArea          int64
# LotShape        object
# LotConfig       object
# dtype: object

# %%
# Transform the category variables in dummies for the correlation matrix and for the models

Lot_DF = pd.get_dummies(Lot_DF,
                        dummy_na=True,
                        prefix_sep='_'
                        )
Lot_DF.boxplot(figsize=(25,15))

# %%
Lot_DF.hist(figsize=(25,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000235A0CB9BC8>,
# ...
#       dtype=object)

# %%
# add the sales price to the Lot DF
Lot_Sales_DF = pd.concat([Lot_DF.drop(['LotShape_nan',
                                       'LotConfig_nan'],
                                       axis=1),
                          SalePrice],
                         axis=1)


# calculate the correlation matrix
corr_Lot = Lot_Sales_DF.corr(method='kendall')

corr_Lot.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_9ca34cfa_5332_11ea_95d0_a85e45c018e7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9ca34cfa_5332_11ea_95d0_a85e45c018e7row0_col1 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_9ca34cfa_5332_11ea_95d0_a85e45c018e7row0_col2 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_9ca34cfa_5332_11ea_95d0_a85e45c018e7row0_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_9ca34cfa_5332_11ea_95d0_a85e45c018e7row0_col4 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_9ca34cfa_5332_11ea_95d0_a85e45c018e7row0_col5 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_9ca34cfa_5332_11ea_95d0_a85e45c018e7row0_col6 {
#             background-color:  #e8d6cc;
#             color:  #000000;
# ...

# %% [markdown]
# ### Main Columns from Lot info to use in the SalePrice
#
# with Lot there is some correlation with ['LotFrontage', 'LotArea', 'LotShape_IR1', 'LotShape_IR2', 'LotShape_Reg', 'LotConfig_CuIDSac', 'LotConfig_FR3']

# %%
Lot_Sales_DF.to_csv('C:/Users/pe-cb/Documents/Projects-onJupyterN/HousePriceAdvancedRegression/Data/Lot_Sales_DF.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-77ffb38fcbec> in <module>
# ----> 1 Lot_Sales_DF.to_csv('C:/Users/pe-cb/Documents/Projects-onJupyterN/HousePriceAdvancedRegression/Data/Lot_Sales_DF.csv', index=True)
#
# NameError: name 'Lot_Sales_DF' is not defined

# %% [markdown]
# ## Above ground information

# %%
# Create Above Ground DataFrame
'''
See the relationship of lot size and type with the price 
'''

GR_DF = HousePrices_train_DF.loc[:,HousePrices_train_DF.columns.str.contains(pat='Gr')|
                                HousePrices_train_DF.columns.str.match('FullBath')|
                                HousePrices_train_DF.columns.str.match('HalfBath')|
                                HousePrices_train_DF.columns.str.match('Bedroom')|
                                HousePrices_train_DF.columns.str.match('Kitchen')]
GR_DF.dtypes

# Transform the category variables in dummies for the correlation matrix and for the models

GR_DF = pd.get_dummies(GR_DF,
                        dummy_na=False,
                        prefix_sep='_'
                        )
GR_DF.boxplot(figsize=(25,15))
GR_DF.hist(figsize=(25,15))

# add the sales price to the Lot DF
GR_Sales_DF = pd.concat([GR_DF,
                         SalePrice],
                         axis=1)


# calculate the correlation matrix
corr_Gr = GR_Sales_DF.corr(method='kendall')

corr_Gr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_dba384c6_56f9_11ea_b2e4_a85e45c018e7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_dba384c6_56f9_11ea_b2e4_a85e45c018e7row0_col1 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_dba384c6_56f9_11ea_b2e4_a85e45c018e7row0_col2 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_dba384c6_56f9_11ea_b2e4_a85e45c018e7row0_col3 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_dba384c6_56f9_11ea_b2e4_a85e45c018e7row0_col4 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_dba384c6_56f9_11ea_b2e4_a85e45c018e7row0_col5 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_dba384c6_56f9_11ea_b2e4_a85e45c018e7row0_col6 {
#             background-color:  #bad0f8;
#             color:  #000000;
# ...

# %%
GR_Sales_DF.to_csv('C:/Users/pe-cb/Documents/Projects-onJupyterN/HousePriceAdvancedRegression/Data/Gr_Sales_DF.csv', index=True)

# %% [markdown]
# ### Basement informationm

# %%
# Create Basement DataFrame
'''
See the relationship of lot size and type with the price 
'''

Bsm_DF = HousePrices_train_DF.loc[:,HousePrices_train_DF.columns.str.contains(pat='Bsm')]
Bsm_DF.dtypes

# Transform the category variables in dummies for the correlation matrix and for the models

Bsm_DF = pd.get_dummies(Bsm_DF,
                        dummy_na=False,
                        prefix_sep='_'
                        )
Bsm_DF.boxplot(figsize=(25,15))
Bsm_DF.hist(figsize=(25,15))

# add the sales price to the Lot DF
Bsm_Sales_DF = pd.concat([Bsm_DF,
                         SalePrice],
                         axis=1)


# calculate the correlation matrix
corr_Bsm = Bsm_Sales_DF.corr(method='kendall')

corr_Bsm.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_6ddbe478_5705_11ea_9126_a85e45c018e7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6ddbe478_5705_11ea_9126_a85e45c018e7row0_col1 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_6ddbe478_5705_11ea_9126_a85e45c018e7row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6ddbe478_5705_11ea_9126_a85e45c018e7row0_col3 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_6ddbe478_5705_11ea_9126_a85e45c018e7row0_col4 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_6ddbe478_5705_11ea_9126_a85e45c018e7row0_col5 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_6ddbe478_5705_11ea_9126_a85e45c018e7row0_col6 {
#             background-color:  #a9c6fd;
#             color:  #000000;
# ...

# %%
Bsm_Sales_DF.to_csv('C:/Users/pe-cb/Documents/Projects-onJupyterN/HousePriceAdvancedRegression/Data/Bsm_Sales_DF.csv', index=True)
